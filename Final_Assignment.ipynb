# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rian Costa Ferreira**
#
# Data Scientist

# %% [markdown]
# “Data science allows me to try various ideas using scientific methods”

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > Hello darkness my old friend
# >
#  - Disturbed
#  - Immortalized
#
# <hr>
#
# My Github [My Github](https://github.com/BayesTheory)
